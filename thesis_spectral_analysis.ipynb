# %%
from __future__ import print_function

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import json
import os
import mne

import ecogtools
from scipy.stats import ttest_ind

# %matplotlib inline

# %%
mne.set_log_level(verbose=False)

# %%
TR_times = {"tmin":-2., "tmax":1.}
TR_baseline = (0., 1.)

# %%
freqs = np.linspace(80, 150, 50)
n_cycles = freqs/2.0
time_bandwidth = 8.0

# %%
patient_num1 = "2002"
channels1 = ['RTG22', 'RTG23', 'RTG24', 'RTG30', 'RTG31', 'RTG32', 'RTG38', 'RTG39', 'RTG40', 'RTG46', 'RTG47', 'RTG48']

# %%
data1 = ecogtools.ToM_Localizer(patient_num1)

# Get the times for task from behavioral data1
tmin = int(data1.trig_and_behav.loc[0, 'trigger_time']-10)
tmax = int(data1.trig_and_behav.loc[59, 'trigger_time']+10)

# Get only physiology data1 that we actually want to look at for task.
data1.phys.crop(tmin=tmin, tmax=tmax)

# Load data1 and pick only channels that we care about.
data1.phys.load_data()
data1.phys.pick_channels(channels1)

data1.initialize_epochs_object(channels1, tmin=-4., tmax=2., baseline=None)

# Calculate power for Time of Response
belief_tr_power1 = mne.time_frequency.tfr_multitaper(data1.epochs['b/time_of_resp'], freqs=freqs, n_cycles=n_cycles,
                       time_bandwidth=time_bandwidth, return_itc=False)
photo_tr_power1 = mne.time_frequency.tfr_multitaper(data1.epochs['p/time_of_resp'], freqs=freqs, n_cycles=n_cycles,
                       time_bandwidth=time_bandwidth, return_itc=False)

TR_power1 = data1.compute_diff_power(belief_tr_power1, photo_tr_power1)
# Out:
# This filename (/Users/andrew_bartuska/lab/ecog_data_analysis/patient_2002/john_2002.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, raw.fif.gz, raw_sss.fif.gz or raw_tsss.fif.gz
# /Users/andrew_bartuska/lab/ecogtools/ecogtools.py:34: RuntimeWarning: This filename (/Users/andrew_bartuska/lab/ecog_data_analysis/patient_2002/john_2002.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, raw.fif.gz, raw_sss.fif.gz or raw_tsss.fif.gz
#   self.phys = mne.io.read_raw_fif(self.ecogfile, preload=False)

# %%
patient_num2 = "2003"
channels2 = ['LTG5', 'LTG6', 'LTG7', 'LTG8', 'LTG13', 'LTG14', 'LTG15', 'LTG16', 'LTG21', 'LTG22', 'LTG23', 'LTG24']

# %%
data2 = ecogtools.ToM_Localizer(patient_num2)

# Get the times for task from behavioral data2
tmin = int(data2.trig_and_behav.loc[0, 'trigger_time']-10)
tmax = int(data2.trig_and_behav.loc[59, 'trigger_time']+10)

# Get only physiology data2 that we actually want to look at for task.
data2.phys.crop(tmin=tmin, tmax=tmax)

# Load data2 and pick only channels that we care about.
data2.phys.load_data()
data2.phys.pick_channels(channels2)

data2.initialize_epochs_object(channels2, tmin=-4., tmax=2., baseline=None)

# Calculate power for Time of Response
belief_tr_power2 = mne.time_frequency.tfr_multitaper(data2.epochs['b/time_of_resp'], freqs=freqs, n_cycles=n_cycles,
                       time_bandwidth=time_bandwidth, return_itc=False)
photo_tr_power2 = mne.time_frequency.tfr_multitaper(data2.epochs['p/time_of_resp'], freqs=freqs, n_cycles=n_cycles,
                       time_bandwidth=time_bandwidth, return_itc=False)
TR_power2 = data2.compute_diff_power(belief_tr_power2, photo_tr_power2)
# Out:
# This filename (/Users/andrew_bartuska/lab/ecog_data_analysis/patient_2003/john_2003.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, raw.fif.gz, raw_sss.fif.gz or raw_tsss.fif.gz
# /Users/andrew_bartuska/lab/ecogtools/ecogtools.py:34: RuntimeWarning: This filename (/Users/andrew_bartuska/lab/ecog_data_analysis/patient_2003/john_2003.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, raw.fif.gz, raw_sss.fif.gz or raw_tsss.fif.gz
#   self.phys = mne.io.read_raw_fif(self.ecogfile, preload=False)

# %%
patient_num3 = "2007"
channels3 = ['RFG5', 'RFG6', 'RFG7', 'RFG8', 'RFG13', 'RFG14', 'RFG15', 'RFG16', 'RFG21', 'RFG22', 'RFG23', 'RFG24']
#channels = ['RFG22', 'RFG23', 'RFG24', 'RFG30', 'RFG31', 'RFG32', 'RFG38', 'RFG39', 'RFG40', 'RFG46', 'RFG47', 'RFG48']

# %%
data3 = ecogtools.ToM_Localizer(patient_num3)

# Get the times for task from behavioral data3
tmin = int(data3.trig_and_behav.loc[0, 'trigger_time']-10)
tmax = int(data3.trig_and_behav.loc[59, 'trigger_time']+10)

# Get only physiology data3 that we actually want to look at for task.
data3.phys.crop(tmin=tmin, tmax=tmax)

# Load data3 and pick only channels that we care about.
data3.phys.load_data()
data3.phys.pick_channels(channels3)

data3.initialize_epochs_object(channels3, tmin=-4., tmax=2., baseline=None)

# Calculate power for Time of Response
belief_tr_power3 = mne.time_frequency.tfr_multitaper(data3.epochs['b/time_of_resp'], freqs=freqs, n_cycles=n_cycles,
                       time_bandwidth=time_bandwidth, return_itc=False)
photo_tr_power3 = mne.time_frequency.tfr_multitaper(data3.epochs['p/time_of_resp'], freqs=freqs, n_cycles=n_cycles,
                       time_bandwidth=time_bandwidth, return_itc=False)
TR_power3 = data3.compute_diff_power(belief_tr_power3, photo_tr_power3)
# Out:
# This filename (/Users/andrew_bartuska/lab/ecog_data_analysis/patient_2007/john_2007.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, raw.fif.gz, raw_sss.fif.gz or raw_tsss.fif.gz
# /Users/andrew_bartuska/lab/ecogtools/ecogtools.py:34: RuntimeWarning: This filename (/Users/andrew_bartuska/lab/ecog_data_analysis/patient_2007/john_2007.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, raw.fif.gz, raw_sss.fif.gz or raw_tsss.fif.gz
#   self.phys = mne.io.read_raw_fif(self.ecogfile, preload=False)

# %% [markdown]
# # Figure 5

# %%
fig, axes = plt.subplots(3, 3)
fig.set_size_inches(6.5, 8.5);

TR_power1.plot([0], axes=axes[0,0], show=False, colorbar=False, baseline=TR_baseline, mode='ratio', dB=True, vmin=-4, vmax=4, **TR_times);
TR_power1.plot([4], axes=axes[0,1], show=False, colorbar=False, baseline=TR_baseline, mode='ratio', dB=True, vmin=-4, vmax=4, **TR_times);
TR_power1.plot([10], axes=axes[0,2], show=False, colorbar=False, baseline=TR_baseline, mode='ratio', dB=True, vmin=-4, vmax=4, **TR_times);
TR_power2.plot([3], axes=axes[1,2], show=False, colorbar=False, baseline=TR_baseline, mode='ratio', dB=True, vmin=-4, vmax=4, **TR_times);
TR_power3.plot([3], axes=axes[2,1], show=False, colorbar=False, baseline=TR_baseline, mode='ratio', dB=True, vmin=-4, vmax=4, **TR_times);
TR_power3.plot([6], axes=axes[2,2], show=False, colorbar=True, baseline=TR_baseline, mode='ratio', dB=True, vmin=-4, vmax=4, **TR_times);

axes[0,0].set_title("RTG 22")
axes[0,1].set_title("Patient 1\nRTG 31")
axes[0,2].set_title("RTG 47")
axes[1,2].set_title("LTG 8")
axes[2,1].set_title("Patient 3\nRFG 8")
axes[2,2].set_title("RFG 15")
plt.figtext(0.475, 0.5, 'Patient 2', color='black', size='large')

axes[0,0].set_xticks([-2000, -1000, 0, 1000])
axes[0,0].set_xticklabels([-2.0, -1.0, 0, 1.0])
axes[0,1].set_xticks([-2000, -1000, 0, 1000])
axes[0,1].set_xticklabels([-2.0, -1.0, 0, 1.0])
axes[0,2].set_xticks([-2000, -1000, 0, 1000])
axes[0,2].set_xticklabels([-2.0, -1.0, 0, 1.0])
axes[1,2].set_xticks([-2000, -1000, 0, 1000])
axes[1,2].set_xticklabels([-2.0, -1.0, 0, 1.0])
axes[2,1].set_xticks([-2000, -1000, 0, 1000])
axes[2,1].set_xticklabels([-2.0, -1.0, 0, 1.0])
axes[2,2].set_xticks([-2000, -1000, 0, 1000])
axes[2,2].set_xticklabels([-2.0, -1.0, 0, 1.0])

axes[0,0].set_xlabel("")
axes[0,1].set_xlabel("")
axes[0,2].set_xlabel("")
axes[1,2].set_xlabel("")
axes[2,1].set_xlabel("Time (s)")
axes[2,2].set_xlabel("Time (s)")

axes[0,0].axvline(x=0, linewidth=2, color='black')
axes[0,1].axvline(x=0, linewidth=2, color='black')
axes[0,2].axvline(x=0, linewidth=2, color='black')
axes[1,2].axvline(x=0, linewidth=2, color='black')
axes[2,1].axvline(x=0, linewidth=2, color='black')
axes[2,2].axvline(x=0, linewidth=2, color='black')

axes[0,0].set_yticks(np.arange(80, 160, 10))
axes[1,2].set_yticks(np.arange(80, 160, 10))
axes[2,1].set_yticks(np.arange(80, 160, 10))
axes[0,1].set_yticks([])
axes[0,2].set_yticks([])
axes[1,0].set_yticks([])
axes[1,1].set_yticks([])
axes[2,0].set_yticks([])
axes[2,2].set_yticks([])

axes[0,1].set_ylabel("")
axes[0,2].set_ylabel("")
axes[2,2].set_ylabel("")

axes[1,0].set_xticklabels([])
axes[1,1].set_xticklabels([])
axes[2,0].set_xticklabels([])
axes[1,0].set_axis_bgcolor('white')
axes[1,1].set_axis_bgcolor('white')
axes[2,0].set_axis_bgcolor('white')

#plt.tight_layout()
#fig.savefig("F5-TF Plots Loc.png", dpi=1000)

# %%
fig, axes = plt.subplots(1, 3, sharey=True)
fig.set_size_inches(10, 5);

TR_power1.plot([0], axes=axes[0], show=False, colorbar=False, baseline=TR_baseline, mode='ratio', dB=True, vmin=-4, vmax=4, **TR_times);
TR_power2.plot([3], axes=axes[1], show=False, colorbar=False, baseline=TR_baseline, mode='ratio', dB=True, vmin=-4, vmax=4, **TR_times);
TR_power3.plot([3], axes=axes[2], show=False, colorbar=False, baseline=TR_baseline, mode='ratio', dB=True, vmin=-4, vmax=4, **TR_times);

axes[0].set_title("RTG 22", size=14)
axes[1].set_title("LTG 8", size=14)
axes[2].set_title("RFG 8", size=14)

axes[0].set_xticks([-2000, -1000, 0, 1000])
axes[0].set_xticklabels([-2.0, -1.0, 0, 1.0])
axes[1].set_xticks([-2000, -1000, 0, 1000])
axes[1].set_xticklabels([-2.0, -1.0, 0, 1.0])
axes[2].set_xticks([-2000, -1000, 0, 1000])
axes[2].set_xticklabels([-2.0, -1.0, 0, 1.0])

axes[0].set_xlabel("Time (s)")
axes[1].set_xlabel("Time (s)")
axes[2].set_xlabel("Time (s)")
axes[1].set_ylabel("")
axes[2].set_ylabel("")

axes[0].axvline(x=0, linewidth=2, color='black')
axes[1].axvline(x=0, linewidth=2, color='black')
axes[2].axvline(x=0, linewidth=2, color='black')

axes[0].set_yticks(np.arange(80, 160, 10));
axes[1].set_yticks(np.arange(80, 160, 10));
axes[2].set_yticks(np.arange(80, 160, 10));

fig.savefig("Poster Loc TF.png", dpi=300)

# %% [markdown]
# # ToM and Attention Task

# %%
data4 = ecogtools.ToM_2010(patient_num1)

# Get the times for task from behavioral data4
tmin = int(data4.trig_and_behav.loc[0, 'trigger_time']-10)
tmax = int(data4.trig_and_behav.loc[59, 'trigger_time']+10)

# Get only physiology data4 that we actually want to look at for task.
data4.phys.crop(tmin=tmin, tmax=tmax)

# Load data4 and pick only channels that we care about.
data4.phys.load_data()
data4.phys.pick_channels(channels1)

data4.initialize_epochs_object(channels1, tmin=-4., tmax=2., baseline=None)


# Calculate power for Time of Response for mental/physical
mental_tr_power4 = mne.time_frequency.tfr_multitaper(data4.epochs['mental/time_of_response'], freqs=freqs, n_cycles=n_cycles,
                       time_bandwidth=time_bandwidth, return_itc=False)
physical_tr_power4 = mne.time_frequency.tfr_multitaper(data4.epochs['physical/time_of_response'], freqs=freqs, n_cycles=n_cycles,
                       time_bandwidth=time_bandwidth, return_itc=False)
TR_power_MP4 = data4.compute_diff_power(mental_tr_power4, physical_tr_power4)

# Calculate power for Time of Response for expected/unexpected
expected_tr_power4 = mne.time_frequency.tfr_multitaper(data4.epochs['expected/time_of_response'], freqs=freqs, n_cycles=n_cycles,
                       time_bandwidth=time_bandwidth, return_itc=False)
unexpected_tr_power4 = mne.time_frequency.tfr_multitaper(data4.epochs['unexpected/time_of_response'], freqs=freqs, n_cycles=n_cycles,
                       time_bandwidth=time_bandwidth, return_itc=False)
TR_power_EU4 = data4.compute_diff_power(expected_tr_power4, unexpected_tr_power4)
# Out:
# This filename (/Users/andrew_bartuska/lab/ecog_data_analysis/patient_2002/john_2002.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, raw.fif.gz, raw_sss.fif.gz or raw_tsss.fif.gz
# /Users/andrew_bartuska/lab/ecogtools/ecogtools.py:34: RuntimeWarning: This filename (/Users/andrew_bartuska/lab/ecog_data_analysis/patient_2002/john_2002.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, raw.fif.gz, raw_sss.fif.gz or raw_tsss.fif.gz
#   self.phys = mne.io.read_raw_fif(self.ecogfile, preload=False)

# %%
data5 = ecogtools.ToM_2010(patient_num2)

# Get the times for task from behavioral data5
tmin = int(data5.trig_and_behav.loc[0, 'trigger_time']-10)
tmax = int(data5.trig_and_behav.loc[59, 'trigger_time']+10)

# Get only physiology data5 that we actually want to look at for task.
data5.phys.crop(tmin=tmin, tmax=tmax)

# Load data5 and pick only channels that we care about.
data5.phys.load_data()
data5.phys.pick_channels(channels2)

data5.initialize_epochs_object(channels2, tmin=-4., tmax=2., baseline=None)


# Calculate power for Time of Response for mental/physical
mental_tr_power5 = mne.time_frequency.tfr_multitaper(data5.epochs['mental/time_of_response'], freqs=freqs, n_cycles=n_cycles,
                       time_bandwidth=time_bandwidth, return_itc=False)
physical_tr_power5 = mne.time_frequency.tfr_multitaper(data5.epochs['physical/time_of_response'], freqs=freqs, n_cycles=n_cycles,
                       time_bandwidth=time_bandwidth, return_itc=False)
TR_power_MP5 = data5.compute_diff_power(mental_tr_power5, physical_tr_power5)

# Calculate power for Time of Response for expected/unexpected
expected_tr_power5 = mne.time_frequency.tfr_multitaper(data5.epochs['expected/time_of_response'], freqs=freqs, n_cycles=n_cycles,
                       time_bandwidth=time_bandwidth, return_itc=False)
unexpected_tr_power5 = mne.time_frequency.tfr_multitaper(data5.epochs['unexpected/time_of_response'], freqs=freqs, n_cycles=n_cycles,
                       time_bandwidth=time_bandwidth, return_itc=False)
TR_power_EU5 = data5.compute_diff_power(expected_tr_power5, unexpected_tr_power5)
# Out:
# This filename (/Users/andrew_bartuska/lab/ecog_data_analysis/patient_2003/john_2003.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, raw.fif.gz, raw_sss.fif.gz or raw_tsss.fif.gz
# /Users/andrew_bartuska/lab/ecogtools/ecogtools.py:34: RuntimeWarning: This filename (/Users/andrew_bartuska/lab/ecog_data_analysis/patient_2003/john_2003.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, raw.fif.gz, raw_sss.fif.gz or raw_tsss.fif.gz
#   self.phys = mne.io.read_raw_fif(self.ecogfile, preload=False)

# %%
data6 = ecogtools.ToM_2010(patient_num3)

# Get the times for task from behavioral data6
tmin = int(data6.trig_and_behav.loc[0, 'trigger_time']-10)
tmax = int(data6.trig_and_behav.loc[59, 'trigger_time']+10)

# Get only physiology data6 that we actually want to look at for task.
data6.phys.crop(tmin=tmin, tmax=tmax)

# Load data6 and pick only channels that we care about.
data6.phys.load_data()
data6.phys.pick_channels(channels3)

data6.initialize_epochs_object(channels3, tmin=-4., tmax=2., baseline=None)


# Calculate power for Time of Response for mental/physical
mental_tr_power6 = mne.time_frequency.tfr_multitaper(data6.epochs['mental/time_of_response'], freqs=freqs, n_cycles=n_cycles,
                       time_bandwidth=time_bandwidth, return_itc=False)
physical_tr_power6 = mne.time_frequency.tfr_multitaper(data6.epochs['physical/time_of_response'], freqs=freqs, n_cycles=n_cycles,
                       time_bandwidth=time_bandwidth, return_itc=False)
TR_power_MP6 = data6.compute_diff_power(mental_tr_power6, physical_tr_power6)

# Calculate power for Time of Response for expected/unexpected
expected_tr_power6 = mne.time_frequency.tfr_multitaper(data6.epochs['expected/time_of_response'], freqs=freqs, n_cycles=n_cycles,
                       time_bandwidth=time_bandwidth, return_itc=False)
unexpected_tr_power6 = mne.time_frequency.tfr_multitaper(data6.epochs['unexpected/time_of_response'], freqs=freqs, n_cycles=n_cycles,
                       time_bandwidth=time_bandwidth, return_itc=False)
TR_power_EU6 = data6.compute_diff_power(expected_tr_power6, unexpected_tr_power6)
# Out:
# This filename (/Users/andrew_bartuska/lab/ecog_data_analysis/patient_2007/john_2007.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, raw.fif.gz, raw_sss.fif.gz or raw_tsss.fif.gz
# /Users/andrew_bartuska/lab/ecogtools/ecogtools.py:34: RuntimeWarning: This filename (/Users/andrew_bartuska/lab/ecog_data_analysis/patient_2007/john_2007.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, raw.fif.gz, raw_sss.fif.gz or raw_tsss.fif.gz
#   self.phys = mne.io.read_raw_fif(self.ecogfile, preload=False)

# %% [markdown]
# # Figure 8

# %%
fig, axes = plt.subplots(2, 2)
fig.set_size_inches(6.5, 8)

TR_power_MP4.plot([1], baseline=TR_baseline, mode='ratio', dB=True, axes=axes[0, 0], vmin=-5., vmax=5., show=False, colorbar=False, **TR_times);
TR_power_EU4.plot([1], baseline=TR_baseline, mode='ratio', dB=True, axes=axes[0, 1], vmin=-5., vmax=5., show=False, colorbar=False, **TR_times);

TR_power_MP4.plot([9], baseline=TR_baseline, mode='ratio', dB=True, axes=axes[1, 0], vmin=-5., vmax=5., show=False, colorbar=False, **TR_times);
TR_power_EU4.plot([9], baseline=TR_baseline, mode='ratio', dB=True, axes=axes[1, 1], vmin=-5., vmax=5., show=False, colorbar=True, **TR_times);

axes[0,0].set_title("mental-physical")
axes[0,1].set_title("expected-unexpected")
axes[1,0].set_title("mental-physical")
axes[1,1].set_title("expected-unexpected")
plt.figtext(0.46, 0.925, 'RTG 23', color='black', size='large')
plt.figtext(0.46, 0.5, 'RTG 46', color='black', size='large')
plt.suptitle("Patient 1", size='x-large')

axes[0,0].set_xticks([-2000, -1000, 0, 1000])
axes[0,0].set_xticklabels([-2.0, -1.0, 0, 1.0])
axes[0,1].set_xticks([-2000, -1000, 0, 1000])
axes[0,1].set_xticklabels([-2.0, -1.0, 0, 1.0])
axes[1,0].set_xticks([-2000, -1000, 0, 1000])
axes[1,0].set_xticklabels([-2.0, -1.0, 0, 1.0])
axes[1,1].set_xticks([-2000, -1000, 0, 1000])
axes[1,1].set_xticklabels([-2.0, -1.0, 0, 1.0])

axes[0,0].set_yticks(np.arange(80, 160, 10))
axes[1,0].set_yticks(np.arange(80, 160, 10))
axes[0,1].set_yticks([])
axes[1,1].set_yticks([])

axes[0,0].axvline(x=0, linewidth=2, color='black')
axes[0,1].axvline(x=0, linewidth=2, color='black')
axes[1,0].axvline(x=0, linewidth=2, color='black')
axes[1,1].axvline(x=0, linewidth=2, color='black')

axes[0,0].set_xlabel("")
axes[0,1].set_xlabel("")
axes[1,0].set_xlabel("Time (s)")
axes[1,1].set_xlabel("Time (s)")
axes[0,1].set_ylabel("")
axes[1,1].set_ylabel("")

#plt.savefig("F8-TF Plots P1 Attention.png", dpi=1000)

# %% [markdown]
# # Figure 9

# %%
fig, axes = plt.subplots(2, 2)
fig.set_size_inches(6.5, 9)

TR_power_MP5.plot([8], baseline=TR_baseline, mode='ratio', dB=True, axes=axes[0, 0], vmin=-5., vmax=5., show=False, colorbar=False, **TR_times);
TR_power_EU5.plot([8], baseline=TR_baseline, mode='ratio', dB=True, axes=axes[0, 1], vmin=-5., vmax=5., show=False, colorbar=False, **TR_times);

TR_power_MP5.plot([10], baseline=TR_baseline, mode='ratio', dB=True, axes=axes[1, 0], vmin=-5., vmax=5., show=False, colorbar=False, **TR_times);
TR_power_EU5.plot([10], baseline=TR_baseline, mode='ratio', dB=True, axes=axes[1, 1], vmin=-5., vmax=5., show=False, colorbar=True, **TR_times);

axes[0,0].set_title("mental-physical")
axes[0,1].set_title("expected-unexpected")
axes[1,0].set_title("mental-physical")
axes[1,1].set_title("expected-unexpected")
plt.figtext(0.46, 0.925, 'LTG 21', color='black', size='large')
plt.figtext(0.46, 0.5, 'LTG 23', color='black', size='large')
plt.suptitle("Patient 2", size='x-large')

axes[0,0].set_xticks([-2000, -1000, 0, 1000])
axes[0,0].set_xticklabels([-2.0, -1.0, 0, 1.0])
axes[0,1].set_xticks([-2000, -1000, 0, 1000])
axes[0,1].set_xticklabels([-2.0, -1.0, 0, 1.0])
axes[1,0].set_xticks([-2000, -1000, 0, 1000])
axes[1,0].set_xticklabels([-2.0, -1.0, 0, 1.0])
axes[1,1].set_xticks([-2000, -1000, 0, 1000])
axes[1,1].set_xticklabels([-2.0, -1.0, 0, 1.0])

axes[0,0].set_yticks(np.arange(80, 160, 10))
axes[1,0].set_yticks(np.arange(80, 160, 10))
axes[0,1].set_yticks([])
axes[1,1].set_yticks([])

axes[0,0].axvline(x=0, linewidth=2, color='black')
axes[0,1].axvline(x=0, linewidth=2, color='black')
axes[1,0].axvline(x=0, linewidth=2, color='black')
axes[1,1].axvline(x=0, linewidth=2, color='black')

axes[0,0].set_xlabel("")
axes[0,1].set_xlabel("")
axes[1,0].set_xlabel("Time (s)")
axes[1,1].set_xlabel("Time (s)")
axes[0,1].set_ylabel("")
axes[1,1].set_ylabel("")

#plt.savefig("F9-TF Plots P2 Attention.png", dpi=1000)

# %% [markdown]
# # Figure 10

# %%
fig, axes = plt.subplots(2, 2)
fig.set_size_inches(6.5, 9)

TR_power_MP6.plot([3], baseline=TR_baseline, mode='ratio', dB=True, axes=axes[0, 0], vmin=-5., vmax=5., show=False, colorbar=False, **TR_times);
TR_power_EU6.plot([3], baseline=TR_baseline, mode='ratio', dB=True, axes=axes[0, 1], vmin=-5., vmax=5., show=False, colorbar=False, **TR_times);

TR_power_MP6.plot([6], baseline=TR_baseline, mode='ratio', dB=True, axes=axes[1, 0], vmin=-5., vmax=5., show=False, colorbar=False, **TR_times);
TR_power_EU6.plot([6], baseline=TR_baseline, mode='ratio', dB=True, axes=axes[1, 1], vmin=-5., vmax=5., show=False, **TR_times);

axes[0,0].set_title("mental-physical")
axes[0,1].set_title("expected-unexpected")
axes[1,0].set_title("mental-physical")
axes[1,1].set_title("expected-unexpected")
plt.figtext(0.46, 0.925, 'RFG 8', color='black', size='large')
plt.figtext(0.46, 0.5, 'RFG 14', color='black', size='large')
plt.suptitle("Patient 3", size='x-large')

axes[0,0].set_xticks([-2000, -1000, 0, 1000])
axes[0,0].set_xticklabels([-2.0, -1.0, 0, 1.0])
axes[0,1].set_xticks([-2000, -1000, 0, 1000])
axes[0,1].set_xticklabels([-2.0, -1.0, 0, 1.0])
axes[1,0].set_xticks([-2000, -1000, 0, 1000])
axes[1,0].set_xticklabels([-2.0, -1.0, 0, 1.0])
axes[1,1].set_xticks([-2000, -1000, 0, 1000])
axes[1,1].set_xticklabels([-2.0, -1.0, 0, 1.0])

axes[0,0].set_yticks(np.arange(80, 160, 10))
axes[1,0].set_yticks(np.arange(80, 160, 10))
axes[0,1].set_yticks([])
axes[1,1].set_yticks([])

axes[0,0].axvline(x=0, linewidth=2, color='black')
axes[0,1].axvline(x=0, linewidth=2, color='black')
axes[1,0].axvline(x=0, linewidth=2, color='black')
axes[1,1].axvline(x=0, linewidth=2, color='black')

axes[0,0].set_xlabel("")
axes[0,1].set_xlabel("")
axes[1,0].set_xlabel("Time (s)")
axes[1,1].set_xlabel("Time (s)")
axes[0,1].set_ylabel("")
axes[1,1].set_ylabel("")

#plt.savefig("F10-TF Plots P3 Attention.png", dpi=1000)

# %%
fig, axes = plt.subplots(1, 4, sharey=True)
fig.set_size_inches(10, 5);

TR_power_MP4.plot([1], baseline=TR_baseline, mode='ratio', dB=True, axes=axes[0], vmin=-5., vmax=5., show=False, colorbar=False, **TR_times);
TR_power_EU4.plot([1], baseline=TR_baseline, mode='ratio', dB=True, axes=axes[1], vmin=-5., vmax=5., show=False, colorbar=False, **TR_times);
TR_power_MP6.plot([3], baseline=TR_baseline, mode='ratio', dB=True, axes=axes[2], vmin=-5., vmax=5., show=False, colorbar=False, **TR_times);
TR_power_EU6.plot([3], baseline=TR_baseline, mode='ratio', dB=True, axes=axes[3], vmin=-5., vmax=5., show=False, colorbar=False, **TR_times);

axes[0].set_title("mental/physical", size=12)
axes[1].set_title("expected/unexpected", size=12)
axes[2].set_title("mental/physical", size=12)
axes[3].set_title("expected/unexpected", size=12)

axes[0].set_xticks([-2000, -1000, 0, 1000])
axes[0].set_xticklabels([-2.0, -1.0, 0, 1.0])
axes[1].set_xticks([-2000, -1000, 0, 1000])
axes[1].set_xticklabels([-2.0, -1.0, 0, 1.0])
axes[2].set_xticks([-2000, -1000, 0, 1000])
axes[2].set_xticklabels([-2.0, -1.0, 0, 1.0])
axes[3].set_xticks([-2000, -1000, 0, 1000])
axes[3].set_xticklabels([-2.0, -1.0, 0, 1.0])

axes[0].set_xlabel("Time (s)")
axes[1].set_xlabel("Time (s)")
axes[2].set_xlabel("Time (s)")
axes[3].set_xlabel("Time (s)")
axes[1].set_ylabel("")
axes[2].set_ylabel("")
axes[3].set_ylabel("")

axes[0].axvline(x=0, linewidth=2, color='black')
axes[1].axvline(x=0, linewidth=2, color='black')
axes[2].axvline(x=0, linewidth=2, color='black')
axes[2].axvline(x=0, linewidth=2, color='black')

axes[0].set_yticks(np.arange(80, 160, 10));

fig.savefig("Poster 2010 TF.png", dpi=300)
